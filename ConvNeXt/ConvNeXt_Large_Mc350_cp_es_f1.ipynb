# %%
import torch, gc
gc.collect()
torch.cuda.empty_cache()

# %%
import GPUtil
GPUtil.showUtilization()
# Out:
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% |  0% |
# |  1 |  0% |  0% |

# %%
import torch
import torch.nn as nn
import torchvision
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from PIL import Image

import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import random
import os
from torchmetrics import F1Score

# %%
random_seed = 12
torch.manual_seed(random_seed)
torch.cuda.manual_seed(random_seed)
torch.cuda.manual_seed_all(random_seed) # if use multi-GPU
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(random_seed)
random.seed(random_seed)

# %%
train_dir_path = '../input/data/train/'
train_image_path = '../input/data/train/images/'

dt_train = pd.read_csv(train_dir_path+'train.csv')
dt_train
# Out:
#           id  gender   race  age                    path
# 0     000001  female  Asian   45  000001_female_Asian_45
# 1     000002  female  Asian   52  000002_female_Asian_52
# 2     000004    male  Asian   54    000004_male_Asian_54
# 3     000005  female  Asian   58  000005_female_Asian_58
# 4     000006  female  Asian   59  000006_female_Asian_59
# ...      ...     ...    ...  ...                     ...
# 2695  006954    male  Asian   19    006954_male_Asian_19
# 2696  006955    male  Asian   19    006955_male_Asian_19
# 2697  006956    male  Asian   19    006956_male_Asian_19
# 2698  006957    male  Asian   20    006957_male_Asian_20
# 2699  006959    male  Asian   19    006959_male_Asian_19
#
# [2700 rows x 5 columns]

# %%
def get_age_range(age):
    if age < 30:
        return 0
    elif 30 <= age < 60:
        return 1
    else:
        return 2

# %%
dt_train['age_range'] = dt_train['age'].apply(lambda x : get_age_range(x))

# %%
dt_train
# Out:
#           id  gender   race  age                    path  age_range
# 0     000001  female  Asian   45  000001_female_Asian_45          1
# 1     000002  female  Asian   52  000002_female_Asian_52          1
# 2     000004    male  Asian   54    000004_male_Asian_54          1
# 3     000005  female  Asian   58  000005_female_Asian_58          1
# 4     000006  female  Asian   59  000006_female_Asian_59          1
# ...      ...     ...    ...  ...                     ...        ...
# 2695  006954    male  Asian   19    006954_male_Asian_19          0
# 2696  006955    male  Asian   19    006955_male_Asian_19          0
# 2697  006956    male  Asian   19    006956_male_Asian_19          0
# 2698  006957    male  Asian   20    006957_male_Asian_20          0
# 2699  006959    male  Asian   19    006959_male_Asian_19          0
#
# [2700 rows x 6 columns]

# %%
train_idx, valid_idx = train_test_split(np.arange(len(dt_train)),
                                       test_size=0.2,
                                       shuffle=True,
                                       stratify=dt_train['age_range'])

# %%
train_image = []
train_label = []

for idx in train_idx:
    path = dt_train.iloc[idx]['path']
    for file_name in [i for i in os.listdir(train_image_path+path) if i[0] != '.']:
        _, file_extension = os.path.splitext(file_name)
        if file_extension not in ['.jpg', '.jpeg', '.png']:
            continue
        train_image.append(train_image_path+path+'/'+file_name)
        train_label.append((path.split('_')[1], path.split('_')[3], file_name.split('.')[0]))

# %%
valid_image = []
valid_label = []

for idx in valid_idx:
    path = dt_train.iloc[idx]['path']
    for file_name in [i for i in os.listdir(train_image_path+path) if i[0] != '.']:
        _, file_extension = os.path.splitext(file_name)
        if file_extension not in ['.jpg', '.jpeg', '.png']:
            continue
        valid_image.append(train_image_path+path+'/'+file_name)
        valid_label.append((path.split('_')[1], path.split('_')[3], file_name.split('.')[0]))

# %%
def onehot_enc(x):
    def gender(i):
        if i == 'male':
            return 0
        elif i == 'female':
            return 3
    def age(j):
        j = int(j)
        if j < 30:
            return 0
        elif j >= 30 and j < 60:
            return 1
        elif j >= 60:
            return 2
    def mask(k):
        if k == 'normal':
            return 12
        elif 'incorrect' in k:
            return 6
        else:
            return 0
    return gender(x[0]) + age(x[1]) + mask(x[2])

# %%
# sr_data = pd.Series(whole_image_path)
# sr_label = pd.Series(whole_target_label)

# %%
train_data = pd.Series(train_image)
train_label = pd.Series(train_label)

valid_data = pd.Series(valid_image)
valid_label = pd.Series(valid_label)

# %%
class Dataset_Mask(Dataset):
    def __init__(self, data, label, encoding=True, midcrop=True, transform=None):
        self.encoding = encoding
        self.midcrop = midcrop
        self.data = data
        self.label = label
        self.transform = transform

        if encoding:
            self.label = self.label.apply(onehot_enc)
        
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        X = Image.open(self.data[idx])
        X = X.crop((17, 70, 367, 420))
        X = self.transform(X)
        y = self.label[idx]
        return X, y

# %%
mask_train_set = Dataset_Mask(data=train_data, label=train_label, transform = transforms.Compose([
                                transforms.RandomResizedCrop((224, 224), interpolation=transforms.InterpolationMode.BICUBIC),
                                transforms.RandomHorizontalFlip(),
                                transforms.ColorJitter(brightness=0.3, contrast=0.3),
                                transforms.ToTensor(),
                                transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
                            ]))

# %%
mask_val_set = Dataset_Mask(data=valid_data, label=valid_label, transform = transforms.Compose([
                                transforms.Resize((224, 224), interpolation=transforms.InterpolationMode.BICUBIC),
                                transforms.ToTensor(),
                                transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
                            ]))

# %%
#t_image = [mask_train_set[i][1] for i in range(len(mask_train_set))]
#v_image = [mask_val_set[i][1] for i in range(len(mask_val_set))]

# %%
#t_df = pd.DataFrame(t_image, columns=['counts'])
#v_df = pd.DataFrame(v_image, columns=['counts'])

# %%
#import seaborn as sns

#fig, axes = plt.subplots(1, 2, figsize=(15, 5))

#sns.countplot(x='counts', data=t_df, ax=axes[0])
#axes[0].set_xlabel("train set labels")
#sns.countplot(x='counts', data=v_df, ax=axes[1])
#axes[1].set_xlabel("valid set labels")

# %%
#print(f'training data size : {len(mask_train_set)}')
#print(f'validation data size : {len(mask_val_set)}')

# %%
batch_size = 2048

train_dataloader_mask = DataLoader(dataset = mask_train_set, batch_size=batch_size, num_workers=2)
val_dataloader_mask = DataLoader(dataset = mask_val_set, batch_size=batch_size, num_workers=2)

# %%
basemodel_convnext_l = torchvision.models.convnext_large(torchvision.models.ConvNeXt_Large_Weights.IMAGENET1K_V1)
print('필요 입력 채널  개수', basemodel_convnext_l.features[0][0].weight.shape[1])
print('네트워크 출력 채널 개수', basemodel_convnext_l.classifier[2].weight.shape[0])
print(basemodel_convnext_l)
# Out:
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:135: UserWarning: Using 'weights' as positional parameter(s) is deprecated since 0.13 and will be removed in 0.15. Please use keyword parameter(s) instead.
#   warnings.warn(
# 필요 입력 채널  개수 3
# 네트워크 출력 채널 개수 1000
# ConvNeXt(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 192, kernel_size=(4, 4), stride=(4, 4))
#       (1): LayerNorm2d((192,), eps=1e-06, elementwise_affine=True)
#     )
#     (1): Sequential(
#       (0): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(192, 192, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=192)
#           (1): Permute()
#           (2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=192, out_features=768, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=768, out_features=192, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#       (1): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(192, 192, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=192)
#           (1): Permute()
#           (2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=192, out_features=768, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=768, out_features=192, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.014285714285714285, mode=row)
#       )
#       (2): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(192, 192, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=192)
#           (1): Permute()
#           (2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=192, out_features=768, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=768, out_features=192, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.02857142857142857, mode=row)
#       )
#     )
#     (2): Sequential(
#       (0): LayerNorm2d((192,), eps=1e-06, elementwise_affine=True)
#       (1): Conv2d(192, 384, kernel_size=(2, 2), stride=(2, 2))
#     )
#     (3): Sequential(
#       (0): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.04285714285714286, mode=row)
#       )
#       (1): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.05714285714285714, mode=row)
#       )
#       (2): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.07142857142857142, mode=row)
#       )
#     )
#     (4): Sequential(
#       (0): LayerNorm2d((384,), eps=1e-06, elementwise_affine=True)
#       (1): Conv2d(384, 768, kernel_size=(2, 2), stride=(2, 2))
#     )
#     (5): Sequential(
#       (0): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.08571428571428572, mode=row)
#       )
#       (1): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#       )
#       (2): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.11428571428571428, mode=row)
#       )
#       (3): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.12857142857142856, mode=row)
#       )
#       (4): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.14285714285714285, mode=row)
#       )
#       (5): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.15714285714285714, mode=row)
#       )
#       (6): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.17142857142857143, mode=row)
#       )
#       (7): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.18571428571428572, mode=row)
#       )
#       (8): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.2, mode=row)
#       )
#       (9): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.21428571428571427, mode=row)
#       )
#       (10): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.22857142857142856, mode=row)
#       )
#       (11): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.24285714285714285, mode=row)
#       )
#       (12): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.2571428571428571, mode=row)
#       )
#       (13): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.2714285714285714, mode=row)
#       )
#       (14): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.2857142857142857, mode=row)
#       )
#       (15): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.3, mode=row)
#       )
#       (16): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.3142857142857143, mode=row)
#       )
#       (17): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.32857142857142857, mode=row)
#       )
#       (18): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.34285714285714286, mode=row)
#       )
#       (19): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.35714285714285715, mode=row)
#       )
#       (20): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.37142857142857144, mode=row)
#       )
#       (21): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.38571428571428573, mode=row)
#       )
#       (22): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.4, mode=row)
#       )
#       (23): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.4142857142857143, mode=row)
#       )
#       (24): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.42857142857142855, mode=row)
#       )
#       (25): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.44285714285714284, mode=row)
#       )
#       (26): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.45714285714285713, mode=row)
#       )
#     )
#     (6): Sequential(
#       (0): LayerNorm2d((768,), eps=1e-06, elementwise_affine=True)
#       (1): Conv2d(768, 1536, kernel_size=(2, 2), stride=(2, 2))
#     )
#     (7): Sequential(
#       (0): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(1536, 1536, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1536)
#           (1): Permute()
#           (2): LayerNorm((1536,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=1536, out_features=6144, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=6144, out_features=1536, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.4714285714285714, mode=row)
#       )
#       (1): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(1536, 1536, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1536)
#           (1): Permute()
#           (2): LayerNorm((1536,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=1536, out_features=6144, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=6144, out_features=1536, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.4857142857142857, mode=row)
#       )
#       (2): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(1536, 1536, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1536)
#           (1): Permute()
#           (2): LayerNorm((1536,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=1536, out_features=6144, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=6144, out_features=1536, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.5, mode=row)
#       )
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): LayerNorm2d((1536,), eps=1e-06, elementwise_affine=True)
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): Linear(in_features=1536, out_features=1000, bias=True)
#   )
# )

# %%
import math
class_num = 18
basemodel_convnext_l.classifier[2] = nn.Linear(in_features=1536, out_features=class_num, bias=True)
nn.init.xavier_uniform_(basemodel_convnext_l.classifier[2].weight)
stdv = 1. / math.sqrt(basemodel_convnext_l.classifier[2].weight.size(1))
basemodel_convnext_l.classifier[2].bias.data.uniform_(-stdv, stdv)
# Out:
# tensor([-0.0127, -0.0147,  0.0134,  0.0004,  0.0047,  0.0212,  0.0067, -0.0157,
#         -0.0237,  0.0238, -0.0092, -0.0043,  0.0108, -0.0006,  0.0170,  0.0118,
#          0.0254,  0.0210])

# %%
#basemodel_convnext_l.classifier[2]
print(basemodel_convnext_l)
# Out:
# ConvNeXt(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 192, kernel_size=(4, 4), stride=(4, 4))
#       (1): LayerNorm2d((192,), eps=1e-06, elementwise_affine=True)
#     )
#     (1): Sequential(
#       (0): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(192, 192, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=192)
#           (1): Permute()
#           (2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=192, out_features=768, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=768, out_features=192, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#       (1): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(192, 192, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=192)
#           (1): Permute()
#           (2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=192, out_features=768, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=768, out_features=192, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.014285714285714285, mode=row)
#       )
#       (2): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(192, 192, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=192)
#           (1): Permute()
#           (2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=192, out_features=768, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=768, out_features=192, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.02857142857142857, mode=row)
#       )
#     )
#     (2): Sequential(
#       (0): LayerNorm2d((192,), eps=1e-06, elementwise_affine=True)
#       (1): Conv2d(192, 384, kernel_size=(2, 2), stride=(2, 2))
#     )
#     (3): Sequential(
#       (0): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.04285714285714286, mode=row)
#       )
#       (1): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.05714285714285714, mode=row)
#       )
#       (2): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.07142857142857142, mode=row)
#       )
#     )
#     (4): Sequential(
#       (0): LayerNorm2d((384,), eps=1e-06, elementwise_affine=True)
#       (1): Conv2d(384, 768, kernel_size=(2, 2), stride=(2, 2))
#     )
#     (5): Sequential(
#       (0): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.08571428571428572, mode=row)
#       )
#       (1): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#       )
#       (2): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.11428571428571428, mode=row)
#       )
#       (3): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.12857142857142856, mode=row)
#       )
#       (4): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.14285714285714285, mode=row)
#       )
#       (5): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.15714285714285714, mode=row)
#       )
#       (6): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.17142857142857143, mode=row)
#       )
#       (7): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.18571428571428572, mode=row)
#       )
#       (8): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.2, mode=row)
#       )
#       (9): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.21428571428571427, mode=row)
#       )
#       (10): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.22857142857142856, mode=row)
#       )
#       (11): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.24285714285714285, mode=row)
#       )
#       (12): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.2571428571428571, mode=row)
#       )
#       (13): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.2714285714285714, mode=row)
#       )
#       (14): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.2857142857142857, mode=row)
#       )
#       (15): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.3, mode=row)
#       )
#       (16): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.3142857142857143, mode=row)
#       )
#       (17): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.32857142857142857, mode=row)
#       )
#       (18): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.34285714285714286, mode=row)
#       )
#       (19): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.35714285714285715, mode=row)
#       )
#       (20): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.37142857142857144, mode=row)
#       )
#       (21): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.38571428571428573, mode=row)
#       )
#       (22): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.4, mode=row)
#       )
#       (23): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.4142857142857143, mode=row)
#       )
#       (24): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.42857142857142855, mode=row)
#       )
#       (25): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.44285714285714284, mode=row)
#       )
#       (26): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.45714285714285713, mode=row)
#       )
#     )
#     (6): Sequential(
#       (0): LayerNorm2d((768,), eps=1e-06, elementwise_affine=True)
#       (1): Conv2d(768, 1536, kernel_size=(2, 2), stride=(2, 2))
#     )
#     (7): Sequential(
#       (0): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(1536, 1536, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1536)
#           (1): Permute()
#           (2): LayerNorm((1536,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=1536, out_features=6144, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=6144, out_features=1536, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.4714285714285714, mode=row)
#       )
#       (1): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(1536, 1536, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1536)
#           (1): Permute()
#           (2): LayerNorm((1536,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=1536, out_features=6144, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=6144, out_features=1536, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.4857142857142857, mode=row)
#       )
#       (2): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(1536, 1536, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1536)
#           (1): Permute()
#           (2): LayerNorm((1536,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=1536, out_features=6144, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=6144, out_features=1536, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.5, mode=row)
#       )
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): LayerNorm2d((1536,), eps=1e-06, elementwise_affine=True)
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): Linear(in_features=1536, out_features=18, bias=True)
#   )
# )

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"using {device}")

if device != "cpu":
    import torch.backends.cudnn as cudnn
    cudnn.benchmark = True
    if torch.cuda.device_count() > 1:
        basemodel_convnext_l = torch.nn.DataParallel(basemodel_convnext_l)

basemodel_convnext_l.to(device)

LEARNING_RATE = 0.0001
NUM_EPOCH = 301

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(basemodel_convnext_l.parameters(), lr=LEARNING_RATE)
# Out:
# using cuda:0

# %%
np.set_printoptions(precision=3)
n_param = 0
for p_idx, (param_name, param) in enumerate(basemodel_convnext_l.named_parameters()):
    if param.requires_grad:
        if param_name.startswith('module.classifier') or param_name.startswith('classifier'):
            param.requires_grad = True  # Train
        else:
            param.requires_grad = False # Freeze

        param_numpy = param.detach().cpu().numpy()
        n_param += len(param_numpy.reshape(-1))
        print ("[%d] name:[%s] shape:[%s]."%(p_idx,param_name,param_numpy.shape))
        print (f"    val:{(param_numpy.reshape(-1)[:5])} -- {param.requires_grad}")
print ("Total number of parameters:[%s]."%(format(n_param,',d')))
# Out:
# [0] name:[module.features.0.0.weight] shape:[(192, 3, 4, 4)].
#     val:[ 0.051  0.029  0.014 -0.006  0.042] -- False
# [1] name:[module.features.0.0.bias] shape:[(192,)].
#     val:[ 0.005  0.011 -0.002  0.01   0.046] -- False
# [2] name:[module.features.0.1.weight] shape:[(192,)].
#     val:[3.158e-01 5.419e-02 4.205e-05 3.202e-01 7.865e-02] -- False
# [3] name:[module.features.0.1.bias] shape:[(192,)].
#     val:[-0.007 -0.002  0.     0.013  0.002] -- False
# [4] name:[module.features.1.0.layer_scale] shape:[(192, 1, 1)].
#     val:[ 0.153 -0.024 -0.062  0.155 -0.082] -- False
# [5] name:[module.features.1.0.block.0.weight] shape:[(192, 1, 7, 7)].
#     val:[-0.001 -0.001  0.     0.004 -0.001] -- False
# [6] name:[module.features.1.0.block.0.bias] shape:[(192,)].
#     val:[-0.004 -0.004 -0.003 -0.005 -0.002] -- False
# [7] name:[module.features.1.0.block.2.weight] shape:[(192,)].
#     val:[1.128 2.323 0.425 1.041 1.755] -- False
# [8] name:[module.features.1.0.block.2.bias] shape:[(192,)].
#     val:[0.517 0.083 0.052 0.551 0.079] -- False
# [9] name:[module.features.1.0.block.3.weight] shape:[(768, 192)].
#     val:[ 0.041 -0.035 -0.143 -0.068 -0.069] -- False
# [10] name:[module.features.1.0.block.3.bias] shape:[(768,)].
#     val:[-0.067 -0.058 -0.072 -0.075 -0.056] -- False
# [11] name:[module.features.1.0.block.5.weight] shape:[(192, 768)].
#     val:[ 0.001 -0.002  0.014  0.082 -0.149] -- False
# [12] name:[module.features.1.0.block.5.bias] shape:[(192,)].
#     val:[ 0.008  0.001 -0.005  0.042 -0.005] -- False
# [13] name:[module.features.1.1.layer_scale] shape:[(192, 1, 1)].
#     val:[-0.235 -0.176 -0.103  0.179 -0.215] -- False
# [14] name:[module.features.1.1.block.0.weight] shape:[(192, 1, 7, 7)].
#     val:[ 0.005 -0.    -0.005  0.     0.013] -- False
# [15] name:[module.features.1.1.block.0.bias] shape:[(192,)].
#     val:[0.002 0.001 0.003 0.001 0.001] -- False
# [16] name:[module.features.1.1.block.2.weight] shape:[(192,)].
#     val:[0.772 3.512 0.856 1.173 1.038] -- False
# [17] name:[module.features.1.1.block.2.bias] shape:[(192,)].
#     val:[-0.12  -0.044 -0.096 -0.153 -0.095] -- False
# [18] name:[module.features.1.1.block.3.weight] shape:[(768, 192)].
#     val:[ 0.027 -0.015 -0.017 -0.027  0.034] -- False
# [19] name:[module.features.1.1.block.3.bias] shape:[(768,)].
#     val:[-0.076 -0.118 -0.048 -0.074 -0.031] -- False
# [20] name:[module.features.1.1.block.5.weight] shape:[(192, 768)].
#     val:[-0.025 -0.05  -0.003 -0.179  0.015] -- False
# [21] name:[module.features.1.1.block.5.bias] shape:[(192,)].
#     val:[-0.043 -0.007 -0.012  0.045  0.003] -- False
# [22] name:[module.features.1.2.layer_scale] shape:[(192, 1, 1)].
#     val:[ 0.256  0.194 -0.139 -0.353 -0.123] -- False
# [23] name:[module.features.1.2.block.0.weight] shape:[(192, 1, 7, 7)].
#     val:[-0.002 -0.003 -0.005  0.006 -0.005] -- False
# [24] name:[module.features.1.2.block.0.bias] shape:[(192,)].
#     val:[ 0.001 -0.001 -0.002 -0.003 -0.007] -- False
# [25] name:[module.features.1.2.block.2.weight] shape:[(192,)].
#     val:[1.058 0.906 2.093 1.359 1.091] -- False
# [26] name:[module.features.1.2.block.2.bias] shape:[(192,)].
#     val:[0.179 0.364 0.217 0.3   0.329] -- False
# [27] name:[module.features.1.2.block.3.weight] shape:[(768, 192)].
#     val:[-0.011 -0.06   0.016 -0.012  0.033] -- False
# [28] name:[module.features.1.2.block.3.bias] shape:[(768,)].
#     val:[-0.009 -0.042 -0.031 -0.058 -0.077] -- False
# [29] name:[module.features.1.2.block.5.weight] shape:[(192, 768)].
#     val:[-0.06   0.08   0.079 -0.051  0.006] -- False
# [30] name:[module.features.1.2.block.5.bias] shape:[(192,)].
#     val:[ 0.083 -0.019 -0.009 -0.068  0.002] -- False
# [31] name:[module.features.2.0.weight] shape:[(192,)].
#     val:[0.024 0.198 0.294 0.048 0.118] -- False
# [32] name:[module.features.2.0.bias] shape:[(192,)].
#     val:[-0.003 -0.006 -0.011 -0.003 -0.001] -- False
# [33] name:[module.features.2.1.weight] shape:[(384, 192, 2, 2)].
#     val:[0.074 0.063 0.082 0.041 0.015] -- False
# [34] name:[module.features.2.1.bias] shape:[(384,)].
#     val:[-0.003 -0.01  -0.004 -0.002  0.013] -- False
# [35] name:[module.features.3.0.layer_scale] shape:[(384, 1, 1)].
#     val:[-0.064  0.084  0.055  0.088 -0.078] -- False
# [36] name:[module.features.3.0.block.0.weight] shape:[(384, 1, 7, 7)].
#     val:[0.016 0.001 0.025 0.079 0.014] -- False
# [37] name:[module.features.3.0.block.0.bias] shape:[(384,)].
#     val:[-0.003  0.     0.002  0.01  -0.002] -- False
# [38] name:[module.features.3.0.block.2.weight] shape:[(384,)].
#     val:[0.793 0.667 0.015 0.678 0.5  ] -- False
# [39] name:[module.features.3.0.block.2.bias] shape:[(384,)].
#     val:[0.068 0.119 0.728 0.019 0.023] -- False
# [40] name:[module.features.3.0.block.3.weight] shape:[(1536, 384)].
#     val:[ 0.054 -0.021 -0.032 -0.029 -0.02 ] -- False
# [41] name:[module.features.3.0.block.3.bias] shape:[(1536,)].
#     val:[-0.032 -0.064 -0.056 -0.089 -0.083] -- False
# [42] name:[module.features.3.0.block.5.weight] shape:[(384, 1536)].
#     val:[ 0.032 -0.121 -0.069  0.049  0.122] -- False
# [43] name:[module.features.3.0.block.5.bias] shape:[(384,)].
#     val:[-0.016  0.003 -0.017 -0.008  0.005] -- False
# [44] name:[module.features.3.1.layer_scale] shape:[(384, 1, 1)].
#     val:[-0.    -0.118  0.136  0.111 -0.168] -- False
# [45] name:[module.features.3.1.block.0.weight] shape:[(384, 1, 7, 7)].
#     val:[-0.015 -0.017 -0.006 -0.025 -0.002] -- False
# [46] name:[module.features.3.1.block.0.bias] shape:[(384,)].
#     val:[-0.003 -0.04  -0.009 -0.003  0.   ] -- False
# [47] name:[module.features.3.1.block.2.weight] shape:[(384,)].
#     val:[0.443 0.363 1.253 0.978 1.265] -- False
# [48] name:[module.features.3.1.block.2.bias] shape:[(384,)].
#     val:[0.118 0.151 0.214 0.068 0.064] -- False
# [49] name:[module.features.3.1.block.3.weight] shape:[(1536, 384)].
#     val:[ 0.168  0.138  0.008 -0.013 -0.024] -- False
# [50] name:[module.features.3.1.block.3.bias] shape:[(1536,)].
#     val:[-0.039 -0.045 -0.056 -0.067 -0.054] -- False
# [51] name:[module.features.3.1.block.5.weight] shape:[(384, 1536)].
#     val:[-0.016 -0.039  0.03   0.044 -0.043] -- False
# [52] name:[module.features.3.1.block.5.bias] shape:[(384,)].
#     val:[ 0.008  0.005  0.045  0.023 -0.063] -- False
# [53] name:[module.features.3.2.layer_scale] shape:[(384, 1, 1)].
#     val:[-0.041  0.113  0.063 -0.14   0.071] -- False
# [54] name:[module.features.3.2.block.0.weight] shape:[(384, 1, 7, 7)].
#     val:[ 0.006 -0.005 -0.005 -0.003  0.   ] -- False
# [55] name:[module.features.3.2.block.0.bias] shape:[(384,)].
#     val:[-0.047 -0.    -0.008 -0.005 -0.017] -- False
# [56] name:[module.features.3.2.block.2.weight] shape:[(384,)].
#     val:[0.988 0.581 1.441 1.591 1.081] -- False
# [57] name:[module.features.3.2.block.2.bias] shape:[(384,)].
#     val:[0.039 0.096 0.192 0.175 0.257] -- False
# [58] name:[module.features.3.2.block.3.weight] shape:[(1536, 384)].
#     val:[ 0.039 -0.02   0.026 -0.011  0.08 ] -- False
# [59] name:[module.features.3.2.block.3.bias] shape:[(1536,)].
#     val:[-0.025 -0.056 -0.064 -0.077 -0.049] -- False
# [60] name:[module.features.3.2.block.5.weight] shape:[(384, 1536)].
#     val:[-0.004  0.081  0.022  0.239 -0.017] -- False
# [61] name:[module.features.3.2.block.5.bias] shape:[(384,)].
#     val:[-0.     0.023 -0.022 -0.025 -0.023] -- False
# [62] name:[module.features.4.0.weight] shape:[(384,)].
#     val:[ 0.129  0.144 -0.     0.092  0.   ] -- False
# [63] name:[module.features.4.0.bias] shape:[(384,)].
#     val:[ 2.699e-03  2.443e-03  7.029e-06 -1.266e-04 -1.654e-06] -- False
# [64] name:[module.features.4.1.weight] shape:[(768, 384, 2, 2)].
#     val:[0.116 0.135 0.076 0.125 0.054] -- False
# [65] name:[module.features.4.1.bias] shape:[(768,)].
#     val:[ 0.025 -0.005 -0.001  0.002  0.002] -- False
# [66] name:[module.features.5.0.layer_scale] shape:[(768, 1, 1)].
#     val:[ 0.013 -0.026 -0.039  0.05  -0.031] -- False
# [67] name:[module.features.5.0.block.0.weight] shape:[(768, 1, 7, 7)].
#     val:[-0.043 -0.013  0.013 -0.018  0.003] -- False
# [68] name:[module.features.5.0.block.0.bias] shape:[(768,)].
#     val:[-0.002  0.001  0.001  0.001  0.005] -- False
# [69] name:[module.features.5.0.block.2.weight] shape:[(768,)].
#     val:[ 0.294  0.856 -0.002  0.828  0.578] -- False
# [70] name:[module.features.5.0.block.2.bias] shape:[(768,)].
#     val:[ 0.087 -0.03   1.396 -0.049 -0.106] -- False
# [71] name:[module.features.5.0.block.3.weight] shape:[(3072, 768)].
#     val:[-0.051 -0.059 -0.128  0.027  0.037] -- False
# [72] name:[module.features.5.0.block.3.bias] shape:[(3072,)].
#     val:[-0.129 -0.114 -0.036 -0.053 -0.049] -- False
# [73] name:[module.features.5.0.block.5.weight] shape:[(768, 3072)].
#     val:[-0.086  0.061 -0.065  0.011 -0.062] -- False
# [74] name:[module.features.5.0.block.5.bias] shape:[(768,)].
#     val:[ 0.039 -0.004  0.012 -0.001 -0.112] -- False
# [75] name:[module.features.5.1.layer_scale] shape:[(768, 1, 1)].
#     val:[-0.03  -0.031 -0.035 -0.086  0.047] -- False
# [76] name:[module.features.5.1.block.0.weight] shape:[(768, 1, 7, 7)].
#     val:[ 0.039  0.027 -0.024  0.138 -0.035] -- False
# [77] name:[module.features.5.1.block.0.bias] shape:[(768,)].
#     val:[-0.008 -0.001 -0.01  -0.007 -0.003] -- False
# [78] name:[module.features.5.1.block.2.weight] shape:[(768,)].
#     val:[0.522 1.008 0.285 0.631 1.003] -- False
# [79] name:[module.features.5.1.block.2.bias] shape:[(768,)].
#     val:[ 0.297  0.012  0.059  0.094 -0.013] -- False
# [80] name:[module.features.5.1.block.3.weight] shape:[(3072, 768)].
#     val:[-0.046 -0.035  0.023 -0.024 -0.056] -- False
# [81] name:[module.features.5.1.block.3.bias] shape:[(3072,)].
#     val:[-0.113 -0.052 -0.04  -0.034 -0.082] -- False
# [82] name:[module.features.5.1.block.5.weight] shape:[(768, 3072)].
#     val:[-0.009 -0.008  0.051  0.008 -0.036] -- False
# [83] name:[module.features.5.1.block.5.bias] shape:[(768,)].
#     val:[-0.052 -0.003  0.018  0.017  0.04 ] -- False
# [84] name:[module.features.5.2.layer_scale] shape:[(768, 1, 1)].
#     val:[-0.051  0.041 -0.061  0.002  0.057] -- False
# [85] name:[module.features.5.2.block.0.weight] shape:[(768, 1, 7, 7)].
#     val:[-0.063 -0.095 -0.083 -0.04  -0.07 ] -- False
# [86] name:[module.features.5.2.block.0.bias] shape:[(768,)].
#     val:[ 0.005 -0.    -0.01   0.009  0.003] -- False
# [87] name:[module.features.5.2.block.2.weight] shape:[(768,)].
#     val:[0.552 0.61  0.902 0.622 0.713] -- False
# [88] name:[module.features.5.2.block.2.bias] shape:[(768,)].
#     val:[ 0.046  0.011 -0.09  -0.185  0.033] -- False
# [89] name:[module.features.5.2.block.3.weight] shape:[(3072, 768)].
#     val:[-0.093  0.047  0.035  0.03   0.1  ] -- False
# [90] name:[module.features.5.2.block.3.bias] shape:[(3072,)].
#     val:[-0.034 -0.036 -0.049 -0.043 -0.063] -- False
# [91] name:[module.features.5.2.block.5.weight] shape:[(768, 3072)].
#     val:[-0.025 -0.034 -0.133 -0.009 -0.057] -- False
# [92] name:[module.features.5.2.block.5.bias] shape:[(768,)].
#     val:[-0.026  0.001 -0.04  -0.002  0.025] -- False
# [93] name:[module.features.5.3.layer_scale] shape:[(768, 1, 1)].
#     val:[ 0.031  0.028 -0.043  0.04   0.043] -- False
# [94] name:[module.features.5.3.block.0.weight] shape:[(768, 1, 7, 7)].
#     val:[0.064 0.039 0.03  0.012 0.009] -- False
# [95] name:[module.features.5.3.block.0.bias] shape:[(768,)].
#     val:[-0.01  -0.007 -0.026 -0.002  0.005] -- False
# [96] name:[module.features.5.3.block.2.weight] shape:[(768,)].
#     val:[0.319 0.92  0.469 0.489 1.206] -- False
# [97] name:[module.features.5.3.block.2.bias] shape:[(768,)].
#     val:[ 0.148  0.19   0.271  0.16  -0.027] -- False
# [98] name:[module.features.5.3.block.3.weight] shape:[(3072, 768)].
#     val:[-0.026  0.065  0.031  0.121  0.047] -- False
# [99] name:[module.features.5.3.block.3.bias] shape:[(3072,)].
#     val:[-0.033 -0.124 -0.057 -0.051 -0.037] -- False
# [100] name:[module.features.5.3.block.5.weight] shape:[(768, 3072)].
#     val:[ 0.042 -0.034  0.053 -0.038 -0.009] -- False
# [101] name:[module.features.5.3.block.5.bias] shape:[(768,)].
#     val:[ 0.113 -0.003  0.016  0.003  0.006] -- False
# [102] name:[module.features.5.4.layer_scale] shape:[(768, 1, 1)].
#     val:[ 0.033 -0.043 -0.044  0.067 -0.09 ] -- False
# [103] name:[module.features.5.4.block.0.weight] shape:[(768, 1, 7, 7)].
#     val:[ 0.035  0.007 -0.022  0.033 -0.034] -- False
# [104] name:[module.features.5.4.block.0.bias] shape:[(768,)].
#     val:[ 0.009  0.004  0.002  0.    -0.001] -- False
# [105] name:[module.features.5.4.block.2.weight] shape:[(768,)].
#     val:[0.306 1.05  0.438 0.545 1.238] -- False
# [106] name:[module.features.5.4.block.2.bias] shape:[(768,)].
#     val:[-0.077 -0.05   0.036  0.01   0.332] -- False
# [107] name:[module.features.5.4.block.3.weight] shape:[(3072, 768)].
#     val:[ 0.011  0.039 -0.094  0.029  0.003] -- False
# [108] name:[module.features.5.4.block.3.bias] shape:[(3072,)].
#     val:[-0.101 -0.032 -0.053 -0.05  -0.049] -- False
# [109] name:[module.features.5.4.block.5.weight] shape:[(768, 3072)].
#     val:[-0.056  0.003  0.036  0.02  -0.051] -- False
# [110] name:[module.features.5.4.block.5.bias] shape:[(768,)].
#     val:[ 0.081 -0.018 -0.014 -0.009 -0.006] -- False
# [111] name:[module.features.5.5.layer_scale] shape:[(768, 1, 1)].
#     val:[ 0.026 -0.04  -0.041 -0.081  0.093] -- False
# [112] name:[module.features.5.5.block.0.weight] shape:[(768, 1, 7, 7)].
#     val:[-0.025  0.04   0.032 -0.1    0.013] -- False
# [113] name:[module.features.5.5.block.0.bias] shape:[(768,)].
#     val:[-0.045 -0.023 -0.009  0.003 -0.008] -- False
# [114] name:[module.features.5.5.block.2.weight] shape:[(768,)].
#     val:[0.592 1.202 0.373 0.723 1.492] -- False
# [115] name:[module.features.5.5.block.2.bias] shape:[(768,)].
#     val:[-0.086  0.485  0.049 -0.016  0.165] -- False
# [116] name:[module.features.5.5.block.3.weight] shape:[(3072, 768)].
#     val:[ 0.014 -0.013 -0.084  0.011 -0.004] -- False
# [117] name:[module.features.5.5.block.3.bias] shape:[(3072,)].
#     val:[-0.046 -0.049 -0.055 -0.048 -0.035] -- False
# [118] name:[module.features.5.5.block.5.weight] shape:[(768, 3072)].
#     val:[ 0.044  0.011 -0.044 -0.006 -0.021] -- False
# [119] name:[module.features.5.5.block.5.bias] shape:[(768,)].
#     val:[ 0.157 -0.01  -0.025  0.001  0.081] -- False
# [120] name:[module.features.5.6.layer_scale] shape:[(768, 1, 1)].
#     val:[ 0.027 -0.113 -0.066 -0.     0.057] -- False
# [121] name:[module.features.5.6.block.0.weight] shape:[(768, 1, 7, 7)].
#     val:[ 0.01  -0.003  0.017 -0.038  0.022] -- False
# [122] name:[module.features.5.6.block.0.bias] shape:[(768,)].
#     val:[-0.011  0.004 -0.002  0.001 -0.012] -- False
# [123] name:[module.features.5.6.block.2.weight] shape:[(768,)].
#     val:[0.49  0.539 1.014 0.602 0.702] -- False
# [124] name:[module.features.5.6.block.2.bias] shape:[(768,)].
#     val:[-0.124 -0.063 -0.321 -0.058 -0.116] -- False
# [125] name:[module.features.5.6.block.3.weight] shape:[(3072, 768)].
#     val:[-0.035 -0.079  0.073  0.052  0.061] -- False
# [126] name:[module.features.5.6.block.3.bias] shape:[(3072,)].
#     val:[-0.044 -0.034 -0.058 -0.043 -0.032] -- False
# [127] name:[module.features.5.6.block.5.weight] shape:[(768, 3072)].
#     val:[ 0.04   0.032 -0.021  0.127 -0.094] -- False
# [128] name:[module.features.5.6.block.5.bias] shape:[(768,)].
#     val:[ 0.173 -0.006 -0.052 -0.     0.013] -- False
# [129] name:[module.features.5.7.layer_scale] shape:[(768, 1, 1)].
#     val:[-2.659e-02 -8.145e-02 -7.995e-02  1.176e-05 -7.429e-02] -- False
# [130] name:[module.features.5.7.block.0.weight] shape:[(768, 1, 7, 7)].
#     val:[ 0.003 -0.012 -0.002 -0.079 -0.006] -- False
# [131] name:[module.features.5.7.block.0.bias] shape:[(768,)].
#     val:[-0.009 -0.    -0.002  0.005 -0.   ] -- False
# [132] name:[module.features.5.7.block.2.weight] shape:[(768,)].
#     val:[0.798 0.316 1.032 0.624 0.591] -- False
# [133] name:[module.features.5.7.block.2.bias] shape:[(768,)].
#     val:[ 0.322 -0.014  0.342 -0.072  0.017] -- False
# [134] name:[module.features.5.7.block.3.weight] shape:[(3072, 768)].
#     val:[ 0.003  0.054  0.052  0.072 -0.067] -- False
# [135] name:[module.features.5.7.block.3.bias] shape:[(3072,)].
#     val:[-0.059 -0.042 -0.042 -0.024 -0.068] -- False
# [136] name:[module.features.5.7.block.5.weight] shape:[(768, 3072)].
#     val:[ 0.019 -0.035 -0.002  0.007  0.072] -- False
# [137] name:[module.features.5.7.block.5.bias] shape:[(768,)].
#     val:[-0.119 -0.008 -0.069 -0.015  0.025] -- False
# [138] name:[module.features.5.8.layer_scale] shape:[(768, 1, 1)].
#     val:[ 0.041 -0.099 -0.085 -0.    -0.107] -- False
# [139] name:[module.features.5.8.block.0.weight] shape:[(768, 1, 7, 7)].
#     val:[-0.053 -0.015  0.    -0.174  0.007] -- False
# [140] name:[module.features.5.8.block.0.bias] shape:[(768,)].
#     val:[-0.028 -0.022 -0.003 -0.001  0.002] -- False
# [141] name:[module.features.5.8.block.2.weight] shape:[(768,)].
#     val:[0.508 0.389 1.133 0.655 0.586] -- False
# [142] name:[module.features.5.8.block.2.bias] shape:[(768,)].
#     val:[ 0.61   0.137  0.35   0.15  -0.003] -- False
# [143] name:[module.features.5.8.block.3.weight] shape:[(3072, 768)].
#     val:[-0.041  0.019 -0.054 -0.014 -0.055] -- False
# [144] name:[module.features.5.8.block.3.bias] shape:[(3072,)].
#     val:[-0.041 -0.057 -0.056 -0.041 -0.045] -- False
# [145] name:[module.features.5.8.block.5.weight] shape:[(768, 3072)].
#     val:[-0.004 -0.023  0.023  0.018 -0.021] -- False
# [146] name:[module.features.5.8.block.5.bias] shape:[(768,)].
#     val:[ 0.137 -0.018 -0.046  0.007  0.001] -- False
# [147] name:[module.features.5.9.layer_scale] shape:[(768, 1, 1)].
#     val:[ 0.03   0.056 -0.054  0.067  0.133] -- False
# [148] name:[module.features.5.9.block.0.weight] shape:[(768, 1, 7, 7)].
#     val:[-0.075 -0.033 -0.064 -0.012 -0.043] -- False
# [149] name:[module.features.5.9.block.0.bias] shape:[(768,)].
#     val:[ 0.053 -0.018 -0.012 -0.001 -0.009] -- False
# [150] name:[module.features.5.9.block.2.weight] shape:[(768,)].
#     val:[0.896 0.397 1.132 0.735 1.068] -- False
# [151] name:[module.features.5.9.block.2.bias] shape:[(768,)].
#     val:[0.205 0.121 0.519 0.122 0.192] -- False
# [152] name:[module.features.5.9.block.3.weight] shape:[(3072, 768)].
#     val:[ 0.036  0.011 -0.074  0.057 -0.124] -- False
# [153] name:[module.features.5.9.block.3.bias] shape:[(3072,)].
#     val:[-0.043 -0.048 -0.038 -0.042 -0.04 ] -- False
# [154] name:[module.features.5.9.block.5.weight] shape:[(768, 3072)].
#     val:[ 0.032 -0.106 -0.007  0.058  0.041] -- False
# [155] name:[module.features.5.9.block.5.bias] shape:[(768,)].
#     val:[ 1.305e-01  2.562e-02 -2.699e-02 -8.059e-05  2.960e-02] -- False
# [156] name:[module.features.5.10.layer_scale] shape:[(768, 1, 1)].
#     val:[ 4.783e-02  1.558e-01  1.065e-01  1.044e-04 -1.256e-01] -- False
# [157] name:[module.features.5.10.block.0.weight] shape:[(768, 1, 7, 7)].
#     val:[ 0.018 -0.002 -0.028  0.076 -0.024] -- False
# [158] name:[module.features.5.10.block.0.bias] shape:[(768,)].
#     val:[ 0.04   0.003  0.011  0.005 -0.004] -- False
# [159] name:[module.features.5.10.block.2.weight] shape:[(768,)].
#     val:[0.583 0.467 1.247 0.781 0.572] -- False
# [160] name:[module.features.5.10.block.2.bias] shape:[(768,)].
#     val:[-0.219 -0.001 -0.55   0.012 -0.126] -- False
# [161] name:[module.features.5.10.block.3.weight] shape:[(3072, 768)].
#     val:[ 0.127 -0.031 -0.069  0.003  0.031] -- False
# [162] name:[module.features.5.10.block.3.bias] shape:[(3072,)].
#     val:[-0.039 -0.05  -0.047 -0.04  -0.053] -- False
# [163] name:[module.features.5.10.block.5.weight] shape:[(768, 3072)].
#     val:[-0.066  0.018  0.012 -0.021  0.044] -- False
# [164] name:[module.features.5.10.block.5.bias] shape:[(768,)].
#     val:[ 0.316  0.01   0.012 -0.005 -0.02 ] -- False
# [165] name:[module.features.5.11.layer_scale] shape:[(768, 1, 1)].
#     val:[-0.024 -0.051 -0.045  0.079  0.107] -- False
# [166] name:[module.features.5.11.block.0.weight] shape:[(768, 1, 7, 7)].
#     val:[ 0.063 -0.043  0.043 -0.068  0.076] -- False
# [167] name:[module.features.5.11.block.0.bias] shape:[(768,)].
#     val:[-0.104  0.005  0.022  0.    -0.001] -- False
# [168] name:[module.features.5.11.block.2.weight] shape:[(768,)].
#     val:[1.439 0.421 0.619 0.945 0.975] -- False
# [169] name:[module.features.5.11.block.2.bias] shape:[(768,)].
#     val:[-0.043  0.006 -0.128  0.024 -0.062] -- False
# [170] name:[module.features.5.11.block.3.weight] shape:[(3072, 768)].
#     val:[ 0.012 -0.09  -0.019 -0.02  -0.129] -- False
# [171] name:[module.features.5.11.block.3.bias] shape:[(3072,)].
#     val:[-0.033 -0.074 -0.054 -0.004 -0.042] -- False
# [172] name:[module.features.5.11.block.5.weight] shape:[(768, 3072)].
#     val:[-0.031 -0.056 -0.001 -0.064  0.005] -- False
# [173] name:[module.features.5.11.block.5.bias] shape:[(768,)].
#     val:[-0.209 -0.027 -0.002 -0.015  0.076] -- False
# [174] name:[module.features.5.12.layer_scale] shape:[(768, 1, 1)].
#     val:[-0.047 -0.161 -0.13  -0.036 -0.158] -- False
# [175] name:[module.features.5.12.block.0.weight] shape:[(768, 1, 7, 7)].
#     val:[-0.026 -0.012  0.017 -0.009  0.018] -- False
# [176] name:[module.features.5.12.block.0.bias] shape:[(768,)].
#     val:[-0.037  0.003  0.01   0.003  0.01 ] -- False
# [177] name:[module.features.5.12.block.2.weight] shape:[(768,)].
#     val:[0.805 0.496 1.191 0.848 0.669] -- False
# [178] name:[module.features.5.12.block.2.bias] shape:[(768,)].
#     val:[ 0.889  0.065 -0.403  0.094  0.134] -- False
# [179] name:[module.features.5.12.block.3.weight] shape:[(3072, 768)].
#     val:[-0.029 -0.037 -0.001  0.007  0.032] -- False
# [180] name:[module.features.5.12.block.3.bias] shape:[(3072,)].
#     val:[-0.042 -0.053 -0.047 -0.038 -0.034] -- False
# [181] name:[module.features.5.12.block.5.weight] shape:[(768, 3072)].
#     val:[ 0.041  0.098 -0.04  -0.023  0.023] -- False
# [182] name:[module.features.5.12.block.5.bias] shape:[(768,)].
#     val:[-0.393 -0.013  0.006  0.011 -0.039] -- False
# [183] name:[module.features.5.13.layer_scale] shape:[(768, 1, 1)].
#     val:[ 0.051  0.172 -0.158 -0.    -0.198] -- False
# [184] name:[module.features.5.13.block.0.weight] shape:[(768, 1, 7, 7)].
#     val:[ 0.02  -0.002  0.034 -0.089  0.02 ] -- False
# [185] name:[module.features.5.13.block.0.bias] shape:[(768,)].
#     val:[ 0.012  0.028 -0.023 -0.003  0.011] -- False
# [186] name:[module.features.5.13.block.2.weight] shape:[(768,)].
#     val:[0.579 0.388 1.036 0.94  0.56 ] -- False
# [187] name:[module.features.5.13.block.2.bias] shape:[(768,)].
#     val:[-0.163 -0.145  0.366 -0.135 -0.089] -- False
# [188] name:[module.features.5.13.block.3.weight] shape:[(3072, 768)].
#     val:[ 0.04  -0.092  0.046 -0.046 -0.062] -- False
# [189] name:[module.features.5.13.block.3.bias] shape:[(3072,)].
#     val:[-0.027 -0.048 -0.053 -0.051 -0.039] -- False
# [190] name:[module.features.5.13.block.5.weight] shape:[(768, 3072)].
#     val:[ 0.022  0.023 -0.028 -0.006  0.02 ] -- False
# [191] name:[module.features.5.13.block.5.bias] shape:[(768,)].
#     val:[0.396 0.012 0.005 0.013 0.002] -- False
# [192] name:[module.features.5.14.layer_scale] shape:[(768, 1, 1)].
#     val:[ 0.031  0.126 -0.119  0.003 -0.176] -- False
# [193] name:[module.features.5.14.block.0.weight] shape:[(768, 1, 7, 7)].
#     val:[-0.031 -0.046 -0.042 -0.022 -0.039] -- False
# [194] name:[module.features.5.14.block.0.bias] shape:[(768,)].
#     val:[ 0.092  0.01  -0.011  0.006  0.016] -- False
# [195] name:[module.features.5.14.block.2.weight] shape:[(768,)].
#     val:[1.328 0.628 0.726 0.85  0.594] -- False
# [196] name:[module.features.5.14.block.2.bias] shape:[(768,)].
#     val:[-0.338 -0.089  0.025 -0.016 -0.269] -- False
# [197] name:[module.features.5.14.block.3.weight] shape:[(3072, 768)].
#     val:[-0.017 -0.017 -0.055 -0.003 -0.005] -- False
# [198] name:[module.features.5.14.block.3.bias] shape:[(3072,)].
#     val:[-0.023 -0.04  -0.023 -0.042 -0.044] -- False
# [199] name:[module.features.5.14.block.5.weight] shape:[(768, 3072)].
#     val:[-0.073  0.008  0.023 -0.026  0.001] -- False
# [200] name:[module.features.5.14.block.5.bias] shape:[(768,)].
#     val:[ 0.299  0.008 -0.004 -0.013  0.022] -- False
# [201] name:[module.features.5.15.layer_scale] shape:[(768, 1, 1)].
#     val:[ 0.064 -0.181 -0.152 -0.001 -0.187] -- False
# [202] name:[module.features.5.15.block.0.weight] shape:[(768, 1, 7, 7)].
#     val:[0.074 0.074 0.075 0.172 0.085] -- False
# [203] name:[module.features.5.15.block.0.bias] shape:[(768,)].
#     val:[-0.02  -0.002  0.013  0.002 -0.004] -- False
# [204] name:[module.features.5.15.block.2.weight] shape:[(768,)].
#     val:[0.712 0.568 0.88  1.13  0.751] -- False
# [205] name:[module.features.5.15.block.2.bias] shape:[(768,)].
#     val:[-0.299  0.144 -0.237 -0.065  0.134] -- False
# [206] name:[module.features.5.15.block.3.weight] shape:[(3072, 768)].
#     val:[ 0.036  0.111 -0.076 -0.073 -0.072] -- False
# [207] name:[module.features.5.15.block.3.bias] shape:[(3072,)].
#     val:[-0.039 -0.034 -0.035 -0.037 -0.03 ] -- False
# [208] name:[module.features.5.15.block.5.weight] shape:[(768, 3072)].
#     val:[ 0.073 -0.022 -0.039  0.031 -0.002] -- False
# [209] name:[module.features.5.15.block.5.bias] shape:[(768,)].
#     val:[ 0.427 -0.016 -0.001  0.007 -0.015] -- False
# [210] name:[module.features.5.16.layer_scale] shape:[(768, 1, 1)].
#     val:[-0.034  0.106  0.105  0.001  0.235] -- False
# [211] name:[module.features.5.16.block.0.weight] shape:[(768, 1, 7, 7)].
#     val:[-0.035  0.016 -0.031  0.064 -0.024] -- False
# [212] name:[module.features.5.16.block.0.bias] shape:[(768,)].
#     val:[ 0.103 -0.015  0.021  0.016  0.022] -- False
# [213] name:[module.features.5.16.block.2.weight] shape:[(768,)].
#     val:[1.785 0.603 0.625 0.77  0.494] -- False
# [214] name:[module.features.5.16.block.2.bias] shape:[(768,)].
#     val:[-1.115 -0.055 -0.059 -0.079 -0.074] -- False
# [215] name:[module.features.5.16.block.3.weight] shape:[(3072, 768)].
#     val:[-0.033 -0.002  0.016  0.002  0.028] -- False
# [216] name:[module.features.5.16.block.3.bias] shape:[(3072,)].
#     val:[-0.051 -0.045 -0.048 -0.036 -0.05 ] -- False
# [217] name:[module.features.5.16.block.5.weight] shape:[(768, 3072)].
#     val:[0.059 0.037 0.036 0.079 0.04 ] -- False
# [218] name:[module.features.5.16.block.5.bias] shape:[(768,)].
#     val:[-0.185  0.009  0.002  0.004 -0.023] -- False
# [219] name:[module.features.5.17.layer_scale] shape:[(768, 1, 1)].
#     val:[-0.037 -0.122  0.114  0.001 -0.251] -- False
# [220] name:[module.features.5.17.block.0.weight] shape:[(768, 1, 7, 7)].
#     val:[-0.009  0.019  0.008 -0.066  0.009] -- False
# [221] name:[module.features.5.17.block.0.bias] shape:[(768,)].
#     val:[-0.084  0.004 -0.003  0.009  0.003] -- False
# [222] name:[module.features.5.17.block.2.weight] shape:[(768,)].
#     val:[1.567 0.604 0.716 0.895 0.631] -- False
# [223] name:[module.features.5.17.block.2.bias] shape:[(768,)].
#     val:[ 0.624  0.051  0.053 -0.099  0.065] -- False
# [224] name:[module.features.5.17.block.3.weight] shape:[(3072, 768)].
#     val:[-0.009  0.047 -0.033 -0.046  0.003] -- False
# [225] name:[module.features.5.17.block.3.bias] shape:[(3072,)].
#     val:[-0.03  -0.034 -0.048 -0.047 -0.03 ] -- False
# [226] name:[module.features.5.17.block.5.weight] shape:[(768, 3072)].
#     val:[-0.108 -0.044  0.056  0.009 -0.027] -- False
# [227] name:[module.features.5.17.block.5.bias] shape:[(768,)].
#     val:[-0.282 -0.014  0.002 -0.002  0.003] -- False
# [228] name:[module.features.5.18.layer_scale] shape:[(768, 1, 1)].
#     val:[-0.078  0.179 -0.184  0.007  0.244] -- False
# [229] name:[module.features.5.18.block.0.weight] shape:[(768, 1, 7, 7)].
#     val:[-0.009  0.015  0.007  0.015 -0.048] -- False
# [230] name:[module.features.5.18.block.0.bias] shape:[(768,)].
#     val:[ 0.038  0.023  0.018 -0.004 -0.   ] -- False
# [231] name:[module.features.5.18.block.2.weight] shape:[(768,)].
#     val:[1.116 0.528 0.851 1.222 0.922] -- False
# [232] name:[module.features.5.18.block.2.bias] shape:[(768,)].
#     val:[-0.064  0.01  -0.231 -0.13   0.171] -- False
# [233] name:[module.features.5.18.block.3.weight] shape:[(3072, 768)].
#     val:[-0.051  0.061  0.028  0.044  0.039] -- False
# [234] name:[module.features.5.18.block.3.bias] shape:[(3072,)].
#     val:[-0.044 -0.039 -0.039 -0.03  -0.049] -- False
# [235] name:[module.features.5.18.block.5.weight] shape:[(768, 3072)].
#     val:[-0.054  0.036  0.036  0.001 -0.019] -- False
# [236] name:[module.features.5.18.block.5.bias] shape:[(768,)].
#     val:[-0.407  0.008  0.007  0.013 -0.001] -- False
# [237] name:[module.features.5.19.layer_scale] shape:[(768, 1, 1)].
#     val:[ 0.089  0.167  0.155 -0.04   0.288] -- False
# [238] name:[module.features.5.19.block.0.weight] shape:[(768, 1, 7, 7)].
#     val:[ 0.019 -0.026  0.01  -0.015  0.064] -- False
# [239] name:[module.features.5.19.block.0.bias] shape:[(768,)].
#     val:[-0.071 -0.011  0.007 -0.004  0.001] -- False
# [240] name:[module.features.5.19.block.2.weight] shape:[(768,)].
#     val:[1.384 0.635 0.845 1.18  0.949] -- False
# [241] name:[module.features.5.19.block.2.bias] shape:[(768,)].
#     val:[-0.04   0.376 -0.068 -0.042 -0.094] -- False
# [242] name:[module.features.5.19.block.3.weight] shape:[(3072, 768)].
#     val:[ 0.035 -0.079  0.06   0.039 -0.052] -- False
# [243] name:[module.features.5.19.block.3.bias] shape:[(3072,)].
#     val:[-0.036 -0.029 -0.029 -0.04  -0.038] -- False
# [244] name:[module.features.5.19.block.5.weight] shape:[(768, 3072)].
#     val:[ 0.006  0.009 -0.078 -0.007  0.046] -- False
# [245] name:[module.features.5.19.block.5.bias] shape:[(768,)].
#     val:[ 0.359 -0.001  0.007 -0.014 -0.008] -- False
# [246] name:[module.features.5.20.layer_scale] shape:[(768, 1, 1)].
#     val:[-0.067  0.118 -0.119 -0.105 -0.287] -- False
# [247] name:[module.features.5.20.block.0.weight] shape:[(768, 1, 7, 7)].
#     val:[-0.026 -0.022  0.021  0.028  0.069] -- False
# [248] name:[module.features.5.20.block.0.bias] shape:[(768,)].
#     val:[ 0.103 -0.02   0.003 -0.013 -0.003] -- False
# [249] name:[module.features.5.20.block.2.weight] shape:[(768,)].
#     val:[1.539 0.756 0.769 1.051 0.695] -- False
# [250] name:[module.features.5.20.block.2.bias] shape:[(768,)].
#     val:[-2.086  0.485 -0.076  0.03   0.007] -- False
# [251] name:[module.features.5.20.block.3.weight] shape:[(3072, 768)].
#     val:[ 0.036 -0.042  0.017 -0.059  0.058] -- False
# [252] name:[module.features.5.20.block.3.bias] shape:[(3072,)].
#     val:[-0.039 -0.051 -0.04  -0.03  -0.04 ] -- False
# [253] name:[module.features.5.20.block.5.weight] shape:[(768, 3072)].
#     val:[ 0.024 -0.016  0.022 -0.037 -0.034] -- False
# [254] name:[module.features.5.20.block.5.bias] shape:[(768,)].
#     val:[-0.164  0.005 -0.009 -0.     0.023] -- False
# [255] name:[module.features.5.21.layer_scale] shape:[(768, 1, 1)].
#     val:[ 0.117  0.164  0.154  0.207 -0.373] -- False
# [256] name:[module.features.5.21.block.0.weight] shape:[(768, 1, 7, 7)].
#     val:[-0.022 -0.024  0.01   0.012  0.013] -- False
# [257] name:[module.features.5.21.block.0.bias] shape:[(768,)].
#     val:[ 0.163  0.016 -0.011  0.01  -0.008] -- False
# [258] name:[module.features.5.21.block.2.weight] shape:[(768,)].
#     val:[1.217 0.742 0.948 1.287 1.026] -- False
# [259] name:[module.features.5.21.block.2.bias] shape:[(768,)].
#     val:[-1.784  0.046  0.058  0.016  0.041] -- False
# [260] name:[module.features.5.21.block.3.weight] shape:[(3072, 768)].
#     val:[ 0.004  0.027  0.025 -0.029 -0.008] -- False
# [261] name:[module.features.5.21.block.3.bias] shape:[(3072,)].
#     val:[-0.038 -0.04  -0.035 -0.038 -0.027] -- False
# [262] name:[module.features.5.21.block.5.weight] shape:[(768, 3072)].
#     val:[-0.021 -0.057 -0.005 -0.056 -0.013] -- False
# [263] name:[module.features.5.21.block.5.bias] shape:[(768,)].
#     val:[0.396 0.003 0.017 0.003 0.02 ] -- False
# [264] name:[module.features.5.22.layer_scale] shape:[(768, 1, 1)].
#     val:[-0.087 -0.126  0.132  0.261  0.326] -- False
# [265] name:[module.features.5.22.block.0.weight] shape:[(768, 1, 7, 7)].
#     val:[-0.009 -0.033  0.006  0.018  0.015] -- False
# [266] name:[module.features.5.22.block.0.bias] shape:[(768,)].
#     val:[ 0.136  0.026  0.003 -0.001  0.001] -- False
# [267] name:[module.features.5.22.block.2.weight] shape:[(768,)].
#     val:[1.697 0.792 0.858 1.148 0.915] -- False
# [268] name:[module.features.5.22.block.2.bias] shape:[(768,)].
#     val:[-3.120e+00 -5.366e-01  2.720e-03  3.561e-03 -3.848e-02] -- False
# [269] name:[module.features.5.22.block.3.weight] shape:[(3072, 768)].
#     val:[ 0.051  0.103  0.087 -0.08  -0.023] -- False
# [270] name:[module.features.5.22.block.3.bias] shape:[(3072,)].
#     val:[-0.038 -0.036 -0.036 -0.034 -0.034] -- False
# [271] name:[module.features.5.22.block.5.weight] shape:[(768, 3072)].
#     val:[-0.012 -0.014 -0.013  0.003 -0.065] -- False
# [272] name:[module.features.5.22.block.5.bias] shape:[(768,)].
#     val:[-0.44  -0.009  0.004  0.009 -0.018] -- False
# [273] name:[module.features.5.23.layer_scale] shape:[(768, 1, 1)].
#     val:[ 0.085  0.107  0.118 -0.423  0.312] -- False
# [274] name:[module.features.5.23.block.0.weight] shape:[(768, 1, 7, 7)].
#     val:[ 0.02   0.024 -0.008 -0.04  -0.026] -- False
# [275] name:[module.features.5.23.block.0.bias] shape:[(768,)].
#     val:[-0.152  0.032  0.008 -0.004  0.024] -- False
# [276] name:[module.features.5.23.block.2.weight] shape:[(768,)].
#     val:[1.633 0.846 0.94  1.119 0.89 ] -- False
# [277] name:[module.features.5.23.block.2.bias] shape:[(768,)].
#     val:[ 3.153 -0.619 -0.048 -0.018 -0.178] -- False
# [278] name:[module.features.5.23.block.3.weight] shape:[(3072, 768)].
#     val:[ 0.008 -0.008  0.07  -0.032 -0.059] -- False
# [279] name:[module.features.5.23.block.3.bias] shape:[(3072,)].
#     val:[-0.03  -0.034 -0.057 -0.024 -0.031] -- False
# [280] name:[module.features.5.23.block.5.weight] shape:[(768, 3072)].
#     val:[-0.042 -0.025 -0.025 -0.104 -0.058] -- False
# [281] name:[module.features.5.23.block.5.bias] shape:[(768,)].
#     val:[ 0.468  0.018  0.004 -0.001 -0.014] -- False
# [282] name:[module.features.5.24.layer_scale] shape:[(768, 1, 1)].
#     val:[-0.082 -0.121  0.129 -0.452 -0.308] -- False
# [283] name:[module.features.5.24.block.0.weight] shape:[(768, 1, 7, 7)].
#     val:[ 0.022  0.014 -0.012 -0.043 -0.026] -- False
# [284] name:[module.features.5.24.block.0.bias] shape:[(768,)].
#     val:[-0.135 -0.047 -0.    -0.003 -0.017] -- False
# [285] name:[module.features.5.24.block.2.weight] shape:[(768,)].
#     val:[1.67  0.922 0.969 0.935 0.913] -- False
# [286] name:[module.features.5.24.block.2.bias] shape:[(768,)].
#     val:[3.451 0.677 0.085 0.004 0.117] -- False
# [287] name:[module.features.5.24.block.3.weight] shape:[(3072, 768)].
#     val:[-0.062  0.04  -0.022  0.026  0.077] -- False
# [288] name:[module.features.5.24.block.3.bias] shape:[(3072,)].
#     val:[-0.04  -0.022 -0.038 -0.039 -0.035] -- False
# [289] name:[module.features.5.24.block.5.weight] shape:[(768, 3072)].
#     val:[ 0.155 -0.017  0.004  0.013  0.006] -- False
# [290] name:[module.features.5.24.block.5.bias] shape:[(768,)].
#     val:[-0.483 -0.008  0.001  0.007  0.01 ] -- False
# [291] name:[module.features.5.25.layer_scale] shape:[(768, 1, 1)].
#     val:[-0.08   0.107 -0.127  0.562 -0.29 ] -- False
# [292] name:[module.features.5.25.block.0.weight] shape:[(768, 1, 7, 7)].
#     val:[-0.035 -0.024  0.028  0.058  0.044] -- False
# [293] name:[module.features.5.25.block.0.bias] shape:[(768,)].
#     val:[ 0.044  0.055  0.01   0.009 -0.02 ] -- False
# [294] name:[module.features.5.25.block.2.weight] shape:[(768,)].
#     val:[1.725 1.069 0.989 0.746 0.936] -- False
# [295] name:[module.features.5.25.block.2.bias] shape:[(768,)].
#     val:[-3.749 -0.619  0.031  0.025  0.263] -- False
# [296] name:[module.features.5.25.block.3.weight] shape:[(3072, 768)].
#     val:[ 0.115 -0.033  0.064 -0.006 -0.068] -- False
# [297] name:[module.features.5.25.block.3.bias] shape:[(3072,)].
#     val:[-0.024 -0.026 -0.044 -0.051 -0.047] -- False
# [298] name:[module.features.5.25.block.5.weight] shape:[(768, 3072)].
#     val:[0.012 0.008 0.079 0.099 0.021] -- False
# [299] name:[module.features.5.25.block.5.bias] shape:[(768,)].
#     val:[-0.452  0.002  0.002 -0.009  0.022] -- False
# [300] name:[module.features.5.26.layer_scale] shape:[(768, 1, 1)].
#     val:[-0.224 -0.11  -0.122 -0.585 -0.233] -- False
# [301] name:[module.features.5.26.block.0.weight] shape:[(768, 1, 7, 7)].
#     val:[ 0.034  0.023 -0.03  -0.056 -0.051] -- False
# [302] name:[module.features.5.26.block.0.bias] shape:[(768,)].
#     val:[-0.014 -0.06  -0.01   0.054  0.006] -- False
# [303] name:[module.features.5.26.block.2.weight] shape:[(768,)].
#     val:[1.793 1.194 1.066 0.149 0.969] -- False
# [304] name:[module.features.5.26.block.2.bias] shape:[(768,)].
#     val:[ 4.038  0.781  0.096 -0.005 -0.162] -- False
# [305] name:[module.features.5.26.block.3.weight] shape:[(3072, 768)].
#     val:[ 0.003  0.003 -0.066  0.032  0.   ] -- False
# [306] name:[module.features.5.26.block.3.bias] shape:[(3072,)].
#     val:[-0.039 -0.041 -0.029 -0.063 -0.024] -- False
# [307] name:[module.features.5.26.block.5.weight] shape:[(768, 3072)].
#     val:[-0.009 -0.021 -0.008 -0.194  0.046] -- False
# [308] name:[module.features.5.26.block.5.bias] shape:[(768,)].
#     val:[-1.785e-01 -5.406e-03 -1.681e-04  8.630e-03  1.818e-02] -- False
# [309] name:[module.features.6.0.weight] shape:[(768,)].
#     val:[0.487 0.938 0.983 0.682 0.477] -- False
# [310] name:[module.features.6.0.bias] shape:[(768,)].
#     val:[-0.127  0.008  0.034  0.025  0.028] -- False
# [311] name:[module.features.6.1.weight] shape:[(1536, 768, 2, 2)].
#     val:[ 0.002  0.002  0.002 -0.    -0.041] -- False
# [312] name:[module.features.6.1.bias] shape:[(1536,)].
#     val:[-0.013 -0.127  0.007  0.023 -0.002] -- False
# [313] name:[module.features.7.0.layer_scale] shape:[(1536, 1, 1)].
#     val:[ 5.375e-04  2.959e-01 -1.145e-01 -6.492e-01  2.008e-03] -- False
# [314] name:[module.features.7.0.block.0.weight] shape:[(1536, 1, 7, 7)].
#     val:[0.089 0.002 0.009 0.053 0.029] -- False
# [315] name:[module.features.7.0.block.0.bias] shape:[(1536,)].
#     val:[-0.033 -0.139 -0.034 -0.124 -0.02 ] -- False
# [316] name:[module.features.7.0.block.2.weight] shape:[(1536,)].
#     val:[1.724 0.552 2.614 2.953 2.86 ] -- False
# [317] name:[module.features.7.0.block.2.bias] shape:[(1536,)].
#     val:[ 0.669 -2.524  0.161  0.351  0.055] -- False
# [318] name:[module.features.7.0.block.3.weight] shape:[(6144, 1536)].
#     val:[-0.015  0.043 -0.004  0.001  0.002] -- False
# [319] name:[module.features.7.0.block.3.bias] shape:[(6144,)].
#     val:[-0.066 -0.056 -0.052 -0.017 -0.023] -- False
# [320] name:[module.features.7.0.block.5.weight] shape:[(1536, 6144)].
#     val:[-0.005  0.058  0.064 -0.021 -0.01 ] -- False
# [321] name:[module.features.7.0.block.5.bias] shape:[(1536,)].
#     val:[ 0.013  0.09  -0.017  0.024 -0.005] -- False
# [322] name:[module.features.7.1.layer_scale] shape:[(1536, 1, 1)].
#     val:[-4.101e-04 -3.828e-01 -1.824e-01  9.085e-01  2.756e-03] -- False
# [323] name:[module.features.7.1.block.0.weight] shape:[(1536, 1, 7, 7)].
#     val:[ 0.061  0.005  0.007  0.036 -0.013] -- False
# [324] name:[module.features.7.1.block.0.bias] shape:[(1536,)].
#     val:[-0.031  0.092 -0.01   0.052 -0.004] -- False
# [325] name:[module.features.7.1.block.2.weight] shape:[(1536,)].
#     val:[8.315e-01 3.433e-01 3.687e-01 8.247e-04 1.186e+00] -- False
# [326] name:[module.features.7.1.block.2.bias] shape:[(1536,)].
#     val:[ 2.045e-01 -2.397e+00  2.938e-01  1.799e-04  4.721e-02] -- False
# [327] name:[module.features.7.1.block.3.weight] shape:[(6144, 1536)].
#     val:[-0.026  0.016  0.023 -0.022  0.083] -- False
# [328] name:[module.features.7.1.block.3.bias] shape:[(6144,)].
#     val:[-0.038 -0.033 -0.06  -0.034 -0.062] -- False
# [329] name:[module.features.7.1.block.5.weight] shape:[(1536, 6144)].
#     val:[ 0.033 -0.004 -0.018  0.09   0.049] -- False
# [330] name:[module.features.7.1.block.5.bias] shape:[(1536,)].
#     val:[-0.001  0.097 -0.011 -0.013  0.022] -- False
# [331] name:[module.features.7.2.layer_scale] shape:[(1536, 1, 1)].
#     val:[-0.006 -0.347 -0.15   0.547  0.05 ] -- False
# [332] name:[module.features.7.2.block.0.weight] shape:[(1536, 1, 7, 7)].
#     val:[ 0.044  0.009  0.014  0.022 -0.012] -- False
# [333] name:[module.features.7.2.block.0.bias] shape:[(1536,)].
#     val:[ 0.006  0.049  0.029  0.162 -0.008] -- False
# [334] name:[module.features.7.2.block.2.weight] shape:[(1536,)].
#     val:[0.824 0.328 0.878 0.076 1.179] -- False
# [335] name:[module.features.7.2.block.2.bias] shape:[(1536,)].
#     val:[ 0.166 -2.173 -0.022  0.093  0.022] -- False
# [336] name:[module.features.7.2.block.3.weight] shape:[(6144, 1536)].
#     val:[ 0.007  0.106 -0.038 -0.016  0.015] -- False
# [337] name:[module.features.7.2.block.3.bias] shape:[(6144,)].
#     val:[-0.029 -0.056 -0.019 -0.038 -0.05 ] -- False
# [338] name:[module.features.7.2.block.5.weight] shape:[(1536, 6144)].
#     val:[-0.087  0.057  0.024 -0.009  0.006] -- False
# [339] name:[module.features.7.2.block.5.bias] shape:[(1536,)].
#     val:[-0.018 -0.026 -0.02  -0.01   0.001] -- False
# [340] name:[module.classifier.0.weight] shape:[(1536,)].
#     val:[ 2.767e-01 -6.323e-05  5.225e-01  1.132e-01  1.972e-01] -- True
# [341] name:[module.classifier.0.bias] shape:[(1536,)].
#     val:[-2.645e-03  2.060e-05 -8.171e-03  1.457e-02  4.970e-03] -- True
# [342] name:[module.classifier.2.weight] shape:[(18, 1536)].
#     val:[ 0.028 -0.027 -0.05   0.037  0.009] -- True
# [343] name:[module.classifier.2.bias] shape:[(18,)].
#     val:[-0.013 -0.015  0.013  0.     0.005] -- True
# Total number of parameters:[196,258,002].

# %%
best_val_acc = 0
best_val_loss = np.inf
patience = 10
cur_count = 0

f1 = F1Score(num_classes=class_num, average='macro').to(device)
best_f1_score = 0

for epoch in range(NUM_EPOCH):
    basemodel_convnext_l.train()
    loss_value = 0
    matches = 0
    for train_batch in tqdm(train_dataloader_mask):
        inputs, labels = train_batch
        inputs = inputs.to(device)
        labels = labels.to(device)
        
        outs = basemodel_convnext_l(inputs)
        preds = torch.argmax(outs, dim=-1)
        loss = criterion(outs, labels)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if epoch % 10 == 0:
            torch.save(basemodel_convnext_l, '../checkpoint/basemodel_convnext_l/checkpoint_ep_%d.pth'% epoch)
        
        loss_value += loss.item()
        matches += (preds == labels).sum().item()
        
        train_loss = loss_value / batch_size
        train_acc = matches / batch_size
        
        loss_value = 0
        matches = 0
    print(f"epoch[{epoch}/{NUM_EPOCH}] training loss {train_loss:.3f}, training accuracy {train_acc:.3f}")
        
    with torch.no_grad():
        basemodel_convnext_l.eval()
        val_loss_items = []
        val_acc_items = []
        for val_batch in tqdm(val_dataloader_mask):
            inputs, labels = val_batch
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            outs = basemodel_convnext_l(inputs)
            preds = torch.argmax(outs, dim=-1)
            
            loss_item = criterion(outs, labels).item()
            acc_item = (labels==preds).sum().item()
            val_loss_items.append(loss_item)
            val_acc_items.append(acc_item)
            
        val_loss = np.sum(val_loss_items) / len(val_dataloader_mask)
        val_acc = np.sum(val_acc_items) / len(mask_val_set)

        f1_score = f1(outs, labels)
        
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            
        if f1_score > best_f1_score:
            best_f1_score = f1_score
#             cur_count = 0
            torch.save(basemodel_convnext_l, '../checkpoint/basemodel_convnext_l/checkpoint_best.pth')
#         else:
#             cur_count += 1
#             if cur_count >= patience:
#                 print("Early Stopping!")
#                 break
            
            
        print(f"[val] acc : {val_acc:.3f}, loss : {val_loss:.3f}, f1 score: {f1_score:.3f}")
        print(f"best acc : {best_val_acc:.3f}, best loss : {best_val_loss:.3f}, best f1 : {best_f1_score:.3f}")
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# epoch[0/301] training loss 0.001, training accuracy 0.062
#   0%|          | 0/2 [00:00<?, ?it/s]
# [val] acc : 0.255, loss : 2.699, f1 score: 0.063
# best acc : 0.255, best loss : 2.699, best f1 : 0.063
#   0%|          | 0/8 [00:00<?, ?it/s]
# epoch[1/301] training loss 0.001, training accuracy 0.083
#   0%|          | 0/2 [00:00<?, ?it/s]
# [val] acc : 0.274, loss : 2.576, f1 score: 0.061
# best acc : 0.274, best loss : 2.576, best f1 : 0.063
#   0%|          | 0/8 [00:00<?, ?it/s]
# epoch[2/301] training loss 0.001, training accuracy 0.098
#   0%|          | 0/2 [00:00<?, ?it/s]
# [val] acc : 0.282, loss : 2.469, f1 score: 0.064
# best acc : 0.282, best loss : 2.469, best f1 : 0.064
#   0%|          | 0/8 [00:00<?, ?it/s]
# epoch[3/301] training loss 0.001, training accuracy 0.088
#   0%|          | 0/2 [00:00<?, ?it/s]
# [val] acc : 0.290, loss : 2.377, f1 score: 0.067
# best acc : 0.290, best loss : 2.377, best f1 : 0.067
#   0%|          | 0/8 [00:00<?, ?it/s]
# epoch[4/301] training loss 0.001, training accuracy 0.090
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
print(f'Best f1 score:{best_f1_score}')

# %%
# meta 데이터와 이미지 경로를 불러옵니다.
test_dir_path = '../input/data/eval/'
test_image_path = '../input/data/eval/images/'

basemodel_convnext_l = torch.load('../checkpoint/basemodel_convnext_l/checkpoint_best.pth')
submission = pd.read_csv(test_dir_path+'info.csv')
submission.head()

# %%
image_paths = [os.path.join(test_image_path, img_id) for img_id in submission.ImageID]
test_image = pd.Series(image_paths)

# %%
class Test_Dataset(Dataset):
    def __init__(self, midcrop=True, transform=None):
        self.midcrop = midcrop
        self.data = test_image
        self.transform = transform
        
    def __len__(self):
        return len(test_image)
    
    def __getitem__(self, idx):
        img = Image.open(self.data[idx])
        img = img.crop((17, 70, 367, 420))
        img = self.transform(img)
        
        return img

# %%
dataset = Test_Dataset(transform = transforms.Compose([
                                transforms.Resize((224, 224), interpolation=transforms.InterpolationMode.BICUBIC),
                                transforms.ToTensor(),
                                transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
                        ]))

loader = DataLoader(
    dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=2
)

# 모델을 정의합니다. (학습한 모델이 있다면 torch.load로 모델을 불러주세요!)
device = torch.device('cuda')
model = basemodel_convnext_l.to(device)
model.eval()

# 모델이 테스트 데이터셋을 예측하고 결과를 저장합니다.
all_predictions = []
for images in loader:
    with torch.no_grad():
        images = images.to(device)
        pred = model(images)
        pred = pred.argmax(dim=-1)
        all_predictions.extend(pred.cpu().numpy())
submission['ans'] = all_predictions

# 제출할 파일을 저장합니다.
submission.to_csv(os.path.join(test_dir_path, 'submission_convnext_l.csv'), index=False)
print('test inference is done!')
